# %% [markdown]
# <a href="https://colab.research.google.com/github/chandumonubol/python/blob/main/Hr_analytics_case_study24/7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://drive.google.com/file/d/1mCiW_8qFi2j9QcqJAXeVWAvNcOoEdvGD/view?usp=sharing

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/people.csv")
df
# Out:
#        satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 0                   0.38            0.53                 2              157
# 1                   0.80            0.86                 5              262
# 2                   0.11            0.88                 7              272
# 3                   0.37            0.52                 2              159
# 4                   0.41            0.50                 2              153
# ...                  ...             ...               ...              ...
# 14994               0.11            0.85                 7              275
# 14995               0.99            0.83                 4              274
# 14996               0.72            0.72                 4              175
# 14997               0.24            0.91                 5              177
# 14998               0.77            0.83                 6              271
#
# ...

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfactoryLevel      14999 non-null  float64
#  1   lastEvaluation         14999 non-null  float64
#  2   numberOfProjects       14999 non-null  int64
#  3   avgMonthlyHours        14999 non-null  int64
#  4   timeSpent.company      14999 non-null  int64
#  5   workAccident           14999 non-null  int64
#  6   left                   14999 non-null  int64
#  7   promotionInLast5years  14999 non-null  int64
#  8   dept                   14999 non-null  object
#  9   salary                 14999 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.1+ MB

# %%
df.isnull().sum()
# Out:
# satisfactoryLevel        0
# lastEvaluation           0
# numberOfProjects         0
# avgMonthlyHours          0
# timeSpent.company        0
# workAccident             0
# left                     0
# promotionInLast5years    0
# dept                     0
# salary                   0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(3008)

# %%
df.drop_duplicates(inplace = True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (11991, 10)

# %%
#employees are leaving why?
#what improvements would you suggest to hr?

# %%
df.columns
# Out:
# Index(['satisfactoryLevel', 'lastEvaluation', 'numberOfProjects',
#        'avgMonthlyHours', 'timeSpent.company', 'workAccident', 'left',
#        'promotionInLast5years', 'dept', 'salary'],
#       dtype='object')

# %%
#numberOfProjects

# %%
sns.countplot(data = df, x ='promotionInLast5years',hue = 'left')
plt.show()

# %%
sns.countplot(data = df, x ='timeSpent.company',hue = 'left')
plt.show()

# %% [markdown]
# Analysis - employees who are having exp 3-5 years are leaving the most.
# suggestion to hr -  if experience is incre then company has to provide hikes,promotions and perks

# %%
#dept --> use count plot
#insight,suggestion

# %%
sns.countplot(data = df, x = 'dept',hue = 'left')
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# analysis - sales,technical,support ,it - employees are leaving the most
#
# sugg - targets should be reachable and incentives should be revised, pressure should reduce

# %%
#avgMonthlyHours -- use approp plot

# %%
df['avgMonthlyHours']
# Out:
# 0        157
# 1        262
# 2        272
# 3        159
# 4        153
#         ...
# 14992    245
# 14995    274
# 14996    175
# 14997    177
# 14998    271
# Name: avgMonthlyHours, Length: 11991, dtype: int64

# %%
sns.countplot(data = df, x = 'avgMonthlyHours',hue ='left')
# Out:
# <Axes: xlabel='avgMonthlyHours', ylabel='count'>

# %%
sns.histplot(data = df, x = 'avgMonthlyHours',hue ='left', kde = True)
# Out:
# <Axes: xlabel='avgMonthlyHours', ylabel='Count'>

# %% [markdown]
# - the employees are leaving the most beacuse there avg working hrs daily is exceeding 11+ hrs which leads to work pressure
#
# - sugg - please revise teh working hours and balance the work accordingly

# %%
sns.countplot(data = df, x= 'salary',hue ='left')
# Out:
# <Axes: xlabel='salary', ylabel='count'>

# %% [markdown]
# ana - people who are getting less salary are leaving the most
#
# sugg - according to the market standards
